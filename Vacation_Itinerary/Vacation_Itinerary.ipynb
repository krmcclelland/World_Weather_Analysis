# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import gmaps
import matplotlib.pyplot as plt
import os
import pandas as pd
import requests

# %matplotlib inline

# Import API key
from config import g_key as gkey

# Configure gmaps API key
gmaps.configure(api_key = gkey)

# Plot Heatmap
fig = gmaps.figure()

# %%
# os.getcwd()

# os.chdir('C:/Users/KellyMcClelland/source/repos/World_Weather_Analysis')

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID            City Country                 Date      Lat       Lng  \
# 0        0          Atuona      PF  2021-12-06 21:29:48  -9.8000 -139.0333
# 1        1           Kapaa      US  2021-12-06 21:29:49  22.0752 -159.3190
# 2        2    Plaster Rock      CA  2021-12-06 21:29:49  46.9065  -67.3900
# 3        3     Kashiwazaki      JP  2021-12-06 21:29:49  37.3667  138.5500
# 4        4  Krasnoznamensk      RU  2021-12-06 21:29:50  55.5994   37.0386
#
#    Max Temp  Humidity  Cloudiness  Wind Speed   Current Description  \
# 0     78.98        68          16       19.91            few clouds
# 1     73.72        94          90        9.22  heavy intensity rain
# 2     40.59        98         100       18.34       overcast clouds
# 3     42.89        88         100        5.57       overcast clouds
# 4     24.84        86          75       13.42         broken clouds
#
#    Rain inches (last 3 hours)  Snow inches (last 3 hours)
# ...

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 30
# What is the maximum temperature you would like for your trip? 70

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID           City Country                 Date      Lat       Lng  \
# 2         2   Plaster Rock      CA  2021-12-06 21:29:49  46.9065  -67.3900
# 3         3    Kashiwazaki      JP  2021-12-06 21:29:49  37.3667  138.5500
# 6         6         Hobart      AU  2021-12-06 21:29:50 -42.8794  147.3294
# 7         7   Punta Arenas      CL  2021-12-06 21:26:32 -53.1500  -70.9167
# 8         8       Luderitz     NaN  2021-12-06 21:29:51 -26.6481   15.1594
# 9         9      Busselton      AU  2021-12-06 21:29:51 -33.6500  115.3333
# 12       12  Mar Del Plata      AR  2021-12-06 21:29:10 -38.0023  -57.5575
# 14       14     Kaitangata      NZ  2021-12-06 21:28:37 -46.2817  169.8464
# 16       16        Mataura      NZ  2021-12-06 21:29:53 -46.1927  168.8643
# 22       22       Tasiilaq      GL  2021-12-06 21:29:55  65.6145  -37.6368
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 2      40.59        98         100       18.34     overcast clouds
# ...

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                       263
# City                          263
# Country                       260
# Date                          263
# Lat                           263
# Lng                           263
# Max Temp                      263
# Humidity                      263
# Cloudiness                    263
# Wind Speed                    263
# Current Description           263
# Rain inches (last 3 hours)    263
# Snow inches (last 3 hours)    263
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()
clean_df.count()
# Out:
# City_ID                       260
# City                          260
# Country                       260
# Date                          260
# Lat                           260
# Lng                           260
# Max Temp                      260
# Humidity                      260
# Cloudiness                    260
# Wind Speed                    260
# Current Description           260
# Rain inches (last 3 hours)    260
# Snow inches (last 3 hours)    260
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country  Max Temp Current Description      Lat       Lng  \
# 2    Plaster Rock      CA     40.59     overcast clouds  46.9065  -67.3900
# 3     Kashiwazaki      JP     42.89     overcast clouds  37.3667  138.5500
# 6          Hobart      AU     57.06          light rain -42.8794  147.3294
# 7    Punta Arenas      CL     51.12          light rain -53.1500  -70.9167
# 9       Busselton      AU     56.08           clear sky -33.6500  115.3333
# 12  Mar Del Plata      AR     65.88           clear sky -38.0023  -57.5575
# 14     Kaitangata      NZ     50.63     overcast clouds -46.2817  169.8464
# 16        Mataura      NZ     58.48           clear sky -46.1927  168.8643
# 22       Tasiilaq      GL     30.36     overcast clouds  65.6145  -37.6368
# 25          Takab      IR     33.04           clear sky  36.4009   47.1133
#
#    Hotel Name
# 2
# 3
# 6
# 7
# 9
# 12
# 14
# 16
# 22
# 25

# %%
# 6a. Set parameters to search for hotels with 5000 meters.

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]

    params = {
    "keyword": "hotel",
    "location": f"{lat},{lng}",
    "radius": 5000,
    "type": "lodging",
    "key": gkey
    }
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    #"https://maps.googleapis.com/maps/api/place/nearbysearch/json?&location=-67.39%2C46.90&radius=5000&type=lodging&key=AIzaSyAA13Noyc1jXaKUzpSh66aKOOwtiUZ2BZs"
    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    print("-------")


    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# -------
# -------
# -------
# -------
# -------
# -------
# -------
# Hotel not found... skipping.
# -------
# -------
# -------
# -------
# -------
# -------
# Hotel not found... skipping.
# -------
# -------
# -------
# -------
# -------
# -------
# -------
# Hotel not found... skipping.
# -------
# -------
# -------
# -------
# -------
# Hotel not found... skipping.
# -------
# -------
# -------
# -------
# -------
# -------
# -------
# Hotel not found... skipping.
# -------
# -------
# -------
# -------
# -------
# -------
# -------
# Hotel not found... skipping.
# -------
# -------
# -------
# -------
# -------
# -------
# -------
# -------
# -------
# -------
# -------
# -------
# Hotel not found... skipping.
# -------
# -------
# -------
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# -------
# -------
# -------
# Hotel not found... skipping.
# -------
# -------
# -------
# -------
# ...

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()

# %%
# 8a. Create the output File (CSV)
output_data_file = os.path.join('WeatherPy_database.csv')

# 8b. Export the City_Data into a csv
#clean_hotel_df.to_csv(output_data_file)

# import from csv
clean_hotel_df = pd.read_csv(output_data_file)

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """

"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
clean_hotel_df.head()
# Out:
#    Unnamed: 0          City Country  Max Temp Current Description      Lat  \
# 0           2  Plaster Rock      CA     40.59     overcast clouds  46.9065
# 1           3   Kashiwazaki      JP     42.89     overcast clouds  37.3667
# 2           6        Hobart      AU     57.06          light rain -42.8794
# 3           7  Punta Arenas      CL     51.12          light rain -53.1500
# 4           9     Busselton      AU     56.08           clear sky -33.6500
#
#         Lng                     Hotel Name
# 0  -67.3900          Settler's Inn & Motel
# 1  138.5500     Hotel Areaone Banjinmisaki
# 2  147.3294  Hotel Grand Chancellor Hobart
# 3  -70.9167            Hotel José Nogueira
# 4  115.3333            The Sebel Busselton

# %%
locations = clean_hotel_df[['Lat','Lng']]
info_box_template='''
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>'''

hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows() ]
fig = gmaps.figure(center = (30.0,31.0), zoom_level = 1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 11a. Add a marker layer for each city to the map. 
max_temp = clean_hotel_df['Max Temp']
cur_desc = clean_hotel_df['Current Description']
fig = gmaps.figure(center = (30.0, 31.0), zoom_level = 1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(marker_layer)

plt.savefig = os.path.join("../Vacation_Search/WeatherPy_vacation_map.png")
fig

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
output_data_file = os.path.join("../Vacation_Search/WeatherPy_vacation.csv")
hotel_df.to_csv(output_data_file, index = False)

# %%
# 6d. Set up the base URL for the Google Directions API to get JSON data.
base_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# 6e. Make request and retrieve the JSON data from the search. 
hotels = requests.get(base_url, params=params).json()

print(hotels)
# Out:
# {'html_attributions': [], 'next_page_token': 'Aap_uEAFNLcwjCzHaoAsansKc6vIBpw-2kMDKPr-vQaM2To_taqn_WglssNIR53vCDjP3YhPwFIVm422XXra44TyDkExC61pvSP2n3Tt15_6qqe067jlFRi8E5EwNUaco7eAaT0i1QBdX_HAtXZ6-IV5H1jkGSaXwsZl56c8direnQsGMD8GeiClCAGtX5UedQ8ROs2JMNAAKKqbQ8WVqQYiRtHTdBodVjxaYh9Bza4KEPaN0aeq6mIdWTKmY5nVfj22w4v-owT7cumOLIFQvE6-MnfHbFyqXtmygkpB1u6x2_fA-n4rskq-9YpSB_6bxpRvBEZjiFIqSbYdnWNP2lCKX3YZLS0TFqngHYOZYcA0HO_rx1VGmbk5SUrwWoF8-PPF3nssUDOYAGBzeXTdqsc66or_t31Tq8j3buGaSo4xfLtwURXGYVhBYJINltoBJWtNFw', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -34.05381, 'lng': 23.37756}, 'viewport': {'northeast': {'lat': -34.05257927010728, 'lng': 23.37890677989272}, 'southwest': {'lat': -34.05527892989272, 'lng': 23.37620712010728}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'icon_background_color': '#909CE1', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet', 'name': 'The Plettenbe
# ...

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %% [markdown]
# # Preferred Distination of Four Cities

# %%
preferred_cities_df.head(25)
# Out:
#     City_ID            City Country                 Date      Lat       Lng  \
# 2         2    Plaster Rock      CA  2021-12-06 21:29:49  46.9065  -67.3900
# 3         3     Kashiwazaki      JP  2021-12-06 21:29:49  37.3667  138.5500
# 6         6          Hobart      AU  2021-12-06 21:29:50 -42.8794  147.3294
# 7         7    Punta Arenas      CL  2021-12-06 21:26:32 -53.1500  -70.9167
# 8         8        Luderitz     NaN  2021-12-06 21:29:51 -26.6481   15.1594
# 9         9       Busselton      AU  2021-12-06 21:29:51 -33.6500  115.3333
# 12       12   Mar Del Plata      AR  2021-12-06 21:29:10 -38.0023  -57.5575
# 14       14      Kaitangata      NZ  2021-12-06 21:28:37 -46.2817  169.8464
# 16       16         Mataura      NZ  2021-12-06 21:29:53 -46.1927  168.8643
# 22       22        Tasiilaq      GL  2021-12-06 21:29:55  65.6145  -37.6368
# 25       25           Takab      IR  2021-12-06 21:29:56  36.4009   47.1133
# ...

# %% [markdown]
# # DataFrame Filter For Each City

# %%
Busselton = preferred_cities_df[preferred_cities_df['City'].str.contains("Busselton")]
Busselton
# Out:
#    City_ID       City Country                 Date    Lat       Lng  Max Temp  \
# 9        9  Busselton      AU  2021-12-06 21:29:51 -33.65  115.3333     56.08
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 9        71           0       17.49           clear sky
#
#    Rain inches (last 3 hours)  Snow inches (last 3 hours)
# 9                         0.0                           0

# %%
Hobart = preferred_cities_df[preferred_cities_df['City'].str.contains("Hobart")]
Hobart
# Out:
#    City_ID    City Country                 Date      Lat       Lng  Max Temp  \
# 6        6  Hobart      AU  2021-12-06 21:29:50 -42.8794  147.3294     57.06
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 6        89          75        5.75          light rain
#
#    Rain inches (last 3 hours)  Snow inches (last 3 hours)
# 6                         0.0                           0

# %%
Esperance = preferred_cities_df[preferred_cities_df['City'].str.contains("Esperance")]
Esperance
# Out:
#      City_ID       City Country                 Date      Lat    Lng  \
# 255      255  Esperance      AU  2021-12-06 21:25:07 -33.8667  121.9
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 255     55.24        73          17       10.54          few clouds
#
#      Rain inches (last 3 hours)  Snow inches (last 3 hours)
# 255                         0.0                           0

# %%
Mount_Gambier = preferred_cities_df[preferred_cities_df['City'].str.contains("Mount Gambier")]
Mount_Gambier
# Out:
#      City_ID           City Country                 Date      Lat       Lng  \
# 198      198  Mount Gambier      AU  2021-12-06 21:30:47 -37.8333  140.7667
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 198     57.11        67          40        9.22    scattered clouds
#
#      Rain inches (last 3 hours)  Snow inches (last 3 hours)
# 198                         0.0                           0

# %% [markdown]
# # Use the List Indexing and Pandas Methods
# #### (Get the Latitude Longitude pairs for each city dataframe as tuples)

# %%
four_cities = pd.concat([Hobart, Busselton, Mount_Gambier, Esperance])
four_cities
# Out:
#      City_ID           City Country                 Date      Lat       Lng  \
# 6          6         Hobart      AU  2021-12-06 21:29:50 -42.8794  147.3294
# 9          9      Busselton      AU  2021-12-06 21:29:51 -33.6500  115.3333
# 198      198  Mount Gambier      AU  2021-12-06 21:30:47 -37.8333  140.7667
# 255      255      Esperance      AU  2021-12-06 21:25:07 -33.8667  121.9000
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 6       57.06        89          75        5.75          light rain
# 9       56.08        71           0       17.49           clear sky
# 198     57.11        67          40        9.22    scattered clouds
# 255     55.24        73          17       10.54          few clouds
#
#      Rain inches (last 3 hours)  Snow inches (last 3 hours)
# 6                           0.0                           0
# 9                           0.0                           0
# 198                         0.0                           0
# ...

# %% [markdown]
# # Cities Latitudes and Longitudes

# %%
columnsData = four_cities.loc[:,['City','Lat','Lng']]
columnsData
# Out:
#               City      Lat       Lng
# 6           Hobart -42.8794  147.3294
# 9        Busselton -33.6500  115.3333
# 198  Mount Gambier -37.8333  140.7667
# 255      Esperance -33.8667  121.9000

# %% [markdown]
# # Direction Layer from GMAPS Documentation

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key= gkey)

# Latitude-longitude pairs
Busselton = (-33.65, 115.3333)
Hobart = (-42.8794, 147.3294)
Esperance = (-33.86677, 121.9)
Mount_Gambier = (-37.8333, 140.7667)

fig = gmaps.figure()
Hobart2Busselton = gmaps.directions_layer(Hobart, Busselton, waypoints=[Mount_Gambier, Esperance])
fig.add_layer(Hobart2Busselton)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Driving Itinerary

# %%
fig = gmaps.figure()
Hobart2Busselton_via_driving = gmaps.directions_layer(
        Hobart, Busselton, waypoints=[Mount_Gambier, Esperance],  
        travel_mode='DRIVING')
fig.add_layer(Hobart2Busselton_via_driving)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Create a Marker Layer Map for the Four Cities.

# %%
four_cities
# Out:
#      City_ID           City Country                 Date      Lat       Lng  \
# 6          6         Hobart      AU  2021-12-06 21:29:50 -42.8794  147.3294
# 9          9      Busselton      AU  2021-12-06 21:29:51 -33.6500  115.3333
# 198      198  Mount Gambier      AU  2021-12-06 21:30:47 -37.8333  140.7667
# 255      255      Esperance      AU  2021-12-06 21:25:07 -33.8667  121.9000
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 6       57.06        89          75        5.75          light rain
# 9       56.08        71           0       17.49           clear sky
# 198     57.11        67          40        9.22    scattered clouds
# 255     55.24        73          17       10.54          few clouds
#
#      Rain inches (last 3 hours)  Snow inches (last 3 hours)
# 6                           0.0                           0
# 9                           0.0                           0
# 198                         0.0                           0
# ...

# %% [markdown]
# # Set Search Parameters For a Hotel.

# %%
params = {
    "radius": 5000,
    "type": "lodging",
    "key": gkey
}
# Iterate through the DataFrame.
for index, row in four_cities.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to the params dictionary as values to the location key.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        four_cities.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
four_cities_hotel_info = [info_box_template.format(**row) for index, row in four_cities.iterrows()]

# %% [markdown]
# # Heatmap of Hotel

# %%
locations = four_cities[["Lat", "Lng"]]
max_temp = four_cities["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=four_cities_hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
